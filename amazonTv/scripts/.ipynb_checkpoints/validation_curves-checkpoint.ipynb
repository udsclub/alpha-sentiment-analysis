# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = DataFrame([['100k', 0.9418, 0.78],
                 ['200k', 0.9483, 0.81],
                 ['500k', 0.9562, 0.84],
                 ['1M', 0.9590, 0.85],
                 ['1,3M', 0.9600, 0.85]], columns = ['n_rows', 'acc', 'f1'])
b = DataFrame([['100k', 0.6874, 0.57],
                 ['200k', 0.7045, 0.60],
                 ['500k', 0.7368, 0.66],
                 ['1M', 0.7313, 0.65],
                 ['1,3M', 0.7334, 0.65]], columns = ['n_rows', 'acc', 'f1'])
c = DataFrame([ ['1:0.25', 0.8045, 0.78],
                ['1:0.5', 0.8162, 0.81],
                ['1:0.75', 0.8227, 0.82],
                ['1:0.9', 0.8165, 0.81],
                ['1:1', 0.8134, 0.81],
                ['1:1.1', 0.8126, 0.80],
                ['1:1.25', 0.8117, 0.80],
                ['1:1.5', 0.8065, 0.79],
                ['1:2.5', 0.7945, 0.76],
                ['1:5', 0.7541, 0.69],
                ['1:6.7', 0.7334, 0.65]], columns = ['n_rows', 'acc', 'f1'])
d = DataFrame([ ['1:0.25', 0.8313, 0.53],
                ['1:0.5', 0.8842, 0.62],
                ['1:0.75', 0.9118, 0.67],
                ['1:0.9', 0.9303, 0.71],
                ['1:1', 0.9332, 0.72],
                ['1:1.1', 0.9332, 0.72],
                ['1:1.25', 0.9378, 0.73],
                ['1:1.5', 0.9397, 0.74],
                ['1:2.5', 0.9460, 0.75],
                ['1:5', 0.9582, 0.78],
                ['1:6.7', 0.9575, 0.76]], columns = ['n_rows', 'acc', 'f1'])
e = DataFrame([ ['1:0.25', 0.6483, 0.24],
                ['1:0.5', 0.7397, 0.30],
                ['1:0.75', 0.7860, 0.34],
                ['1:0.9', 0.8413, 0.40],
                ['1:1', 0.9332, 0.72],
                ['1:1.1', 0.8577, 0.42],
                ['1:1.25', 0.8629, 0.42],
                ['1:1.5', 0.8889, 0.47],
                ['1:2.5', 0.9023, 0.49],
                ['1:5', 0.9457, 0.59],
                ['1:6.7', 0.9576, 0.62]], columns = ['n_rows', 'acc', 'f1'])
f = DataFrame([ ['1:0.25', 0.7882, 0.56],
                ['1:0.5', 0.8366, 0.62],
                ['1:0.75', 0.8586, 0.65],
                ['1:0.9', 0.8824, 0.69],
                ['1:1', 0.9332, 0.72],
                ['1:1.1', 0.8918, 0.70],
                ['1:1.25', 0.9037, 0.72],
                ['1:1.5', 0.9153, 0.74],
                ['1:2.5', 0.9216, 0.75],
                ['1:5', 0.9394, 0.78],
                ['1:6.7', 0.9408,  0.77]], columns = ['n_rows', 'acc', 'f1'])

# %%
plt.figure(figsize=((16,9)))
xs = [i for i, _ in enumerate(a.acc)]
plt.plot(xs, a.acc, 'g-', label='Accuracy')
plt.plot(xs, a.f1, 'r-', label='F1 score')
# plt.axis([0, 4, 0, 1.])
plt.xlabel("number of train samples")
plt.xticks(xs, a.n_rows)
plt.title("Amazon test dataset")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,9))
xs = [i for i, _ in enumerate(b.acc)]
plt.plot(xs, b.acc, 'g-', label='Accuracy')
plt.plot(xs, b.f1, 'r-', label='F1 score')
# plt.axis([0, 4, .9, 1.])
plt.xlabel("number of train samples")
plt.xticks(xs, b.n_rows)
plt.title("Test data")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,9))
xs = [i for i, _ in enumerate(c.acc)]
plt.plot(xs, c.acc, 'g-', label='Accuracy')
plt.plot(xs, c.f1, 'r-', label='F1 score')
# plt.axis([0, 4, .9, 1.])
plt.xlabel("number of train samples")
plt.xticks(xs, c.n_rows)
plt.title("Test data")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,9))
xs = [i for i, _ in enumerate(d.acc)]
plt.plot(xs, d.acc, 'g-', label='Accuracy')
plt.plot(xs, d.f1, 'r-', label='F1 score')
# plt.axis([0, 4, .9, 1.])
plt.xlabel("number of train samples")
plt.xticks(xs, d.n_rows)
plt.title("Digital Music")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,9))
xs = [i for i, _ in enumerate(e.acc)]
plt.plot(xs, e.acc, 'g-', label='Accuracy')
plt.plot(xs, e.f1, 'r-', label='F1 score')
# plt.axis([0, 4, .9, 1.])
plt.xlabel("number of train samples")
plt.xticks(xs, e.n_rows)
plt.title("Office Products")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,9))
xs = [i for i, _ in enumerate(f.acc)]
plt.plot(xs, f.acc, 'g-', label='Accuracy')
plt.plot(xs, f.f1, 'r-', label='F1 score')
# plt.axis([0, 4, .9, 1.])
plt.xlabel("number of train samples")
plt.xticks(xs, f.n_rows)
plt.title("Video Games")
plt.legend()
plt.show()
